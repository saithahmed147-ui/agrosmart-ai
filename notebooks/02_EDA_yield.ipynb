# %% [markdown]
# # 02 — EDA: Yield & soil-yield datasets
# Explores `yield_df.csv` and **`crop_yield_final.csv`** (soil inputs + yield) as a future unified model path.

# %%
import pandas as pd
from pathlib import Path
root = Path('..')
y = pd.read_csv(root / 'data/raw/yield_df.csv')
c = pd.read_csv(root / 'data/raw/crop_yield_final.csv')
print('yield_df', y.shape, y.columns.tolist())
print('crop_yield_final', c.shape, c.columns.tolist())
print(c.describe())
