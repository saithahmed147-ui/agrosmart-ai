# %% [markdown]
# # 01 — EDA: Crop datasets
# Loads `Crop_recommendation.csv` and `sensor_Crop_Dataset.csv` from `data/raw/`.

# %%
import pandas as pd
from pathlib import Path
root = Path('..')
df1 = pd.read_csv(root / 'data/raw/Crop_recommendation.csv')
df2 = pd.read_csv(root / 'data/raw/sensor_Crop_Dataset.csv')
print(df1.shape, df2.shape)
print(df1.head())
print(df2.head())
